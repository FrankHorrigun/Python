# %% [markdown]
# <a href="https://colab.research.google.com/github/FrankHorrigun/Python/blob/main/Sem_010.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/sample_data/california_housing_train.csv')
df1 = pd.read_csv('/content/sample_data/california_housing_test.csv')

# %%
df.shape
# Out:
# (17000, 9)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.scatterplot(data=df, x="longitude", y="latitude")
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
# Изобразите отношение households к population с
# помощью точечного графика

# %%
sns.scatterplot(data=df, x="households", y="population")
# Out:
# <Axes: xlabel='households', ylabel='population'>

# %%
sns.scatterplot(data=df, x="households", y=df.query('population<35000')["population"])
# Out:
# <Axes: xlabel='households', ylabel='population'>

# %%
# Визуализировать longitude по отношения к
# median_house_value, используя линейный график

# %%
sns.relplot(x="longitude", y="median_house_value", kind="line", data=df)

# %%
sns.relplot(x=df.longitude, y=df.median_house_value, kind="line")

# %%
# Представить гистограмму по housing_median_age

# %%
sns.histplot(x=df.query('housing_median_age>50')["housing_median_age"])
# Out:
# <Axes: xlabel='housing_median_age', ylabel='Count'>

# %%
def age(x):
  if x <= 10:
    return '0-10'
  elif x > 10 and x <= 20:
    return '11-20'
  elif x > 20 and x <= 30:
    return '21-30'
  elif x > 30 and x <= 40:
    return '31-40'
  elif x > 40 and x <= 50:
    return '41-50'
  elif x > 50 and x <= 60:
    return '51-60'

# %%
df['age'] = df.housing_median_age.apply(age)

# %%
sns.histplot(x=df.age)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(x=df.query('housing_median_age>20 and housing_median_age<50')['housing_median_age'])
# Out:
# <Axes: xlabel='housing_median_age', ylabel='Count'>

# %%
# Изобразить гистограмму по median_house_value с
# оттенком housing_median_age

# %%
sns.histplot(data=df, x="median_house_value", hue="housing_median_age")
# Out:
# <Axes: xlabel='median_house_value', ylabel='Count'>

# %%
def age(x):
  if x<=10:
    return "0-10"
  elif 10<x<=20:
    return "11-20"
  elif 20<x<=30:
    return "21-30"
  elif 30<x<=40:
    return "31-40"
  elif 40<x<=50:
    return "41-50"
  elif 50<x<=60:
    return "51-60"
  elif 60<x<=70:
    return "61-70"
  elif 70<x<=80:
    return "71-80"
  elif 80<x<=90:
    return "81-90"
df1['age'] = df1.housing_median_age.apply(age)
plt.figure(figsize=(10, 60))
sns.displot(data=df1, x="median_house_value", hue="age")

# %%
penguins = sns.load_dataset("penguins")
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.scatterplot(x=penguins.bill_length_mm, y=penguins.bill_depth_mm, hue=penguins.sex)
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
cols=['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g', 'sex']
g=sns.PairGrid(penguins[cols], hue='sex')
g.map(sns.scatterplot)

# %%
# Создать новый столбец в таблице с
# пингвинами, который будет отвечать за
# показатель длины клюва пингвина.
# high - длинный(от 42)
# middle - средний(от 35 до 42)
# low - маленький(до 35)

# %%
def bill_length(x):
  if x>42:
    return 'high'
  elif 35<x<=42:
    return 'midlle'
  else:
    return 'low'
penguins['bill_length'] = penguins.bill_length_mm.apply(bill_length)
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex bill_length
# 0         3750.0    Male      midlle
# ...

# %%
# Изобразить гистограмму по flipper_length_mm
# с оттенком height_group. Сделать анализ

# %%
sns.histplot(data=penguins, x='flipper_length_mm', hue='bill_length')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>

# %%
# альтернативная библиотека Plotly. Интерактивная

# %%
# В ячейке ниже представлен код генерирующий DataFrame, которая состоит всего из 1 столбца. Ваша задача перевести его в one hot вид. Сможете ли вы это сделать без get_dummies?

# %%
import random
lst = ['robot'] * 3
lst += ['human'] * 3
# lst+=['alien']*3
random.shuffle(lst)
data = pd.DataFrame({'whoAmI':lst})
data.head()

# %%
data
# Out:
#   whoAmI
# 0  human
# 1  robot
# 2  human
# 3  robot
# 4  human
# 5  robot

# %%
df3=pd.get_dummies(data['whoAmI'])
df3
# Out:
#    human  robot
# 0      1      0
# 1      0      1
# 2      1      0
# 3      0      1
# 4      1      0
# 5      0      1

# %%
import numpy as np
print(lst)
new_lst = list(enumerate(set(lst)))
print(new_lst)
# new_df = np.array(new_lst)
# new_df
# Out:
# ['human', 'robot', 'human', 'robot', 'human', 'robot']
# [(0, 'robot'), (1, 'human')]

# %%
def gender(x, new_lst):
  result=[]
  for j in range(len(new_lst)):
    if x in new_lst[j]:
      result.append(j)
  return result

# %%
print(lst)
print(gender(lst, new_lst))
# Out:
# ['human', 'robot', 'robot', 'robot', 'human', 'human']
# []

# %%
data['robot'] = data.whoAmI.apply(lambda x: 1 if x == 'robot' else 0)
data['robot'] = data.whoAmI.apply(lambda x: 1 if x == 'robot' else 0)
data
# Out:
#   whoAmI  robot  human
# 0  human      0      0
# 1  human      0      0
# 2  robot      1      1
# 3  robot      1      1
# 4  human      0      0
# 5  robot      1      1

# %%
data
data['robot'] = np.where(data.whoAmI=='robot', 1, 0)
data['human'] = np.where(data.whoAmI=='human', 1, 0)
data
# data.drop('whoAmI', axis=1, inplace=True)
data
# Out:
#   whoAmI  robot  human
# 0  human      0      1
# 1  robot      1      0
# 2  human      0      1
# 3  robot      1      0
# 4  human      0      1
# 5  robot      1      0
